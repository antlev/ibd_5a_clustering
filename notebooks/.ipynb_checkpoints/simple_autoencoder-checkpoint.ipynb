# %% [markdown]
# # Simple autoencoder - Mnist
#
# ## Import Mnist data

# %%
from keras.datasets import mnist
import numpy as np
(x_train, y_train), (x_test, _) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# Using TensorFlow backend.
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Autoencoder structure

# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 32  

input_img = Input(shape=(784,))
decoder_input = Input(shape=(encoding_dim,))

encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

encoder = Model(input_img, encoded)
autoencoder=Model(input_img, decoded)

decoder_layer = autoencoder.layers[-1]
decoder = Model(decoder_input, decoder_layer(decoder_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 3s 54us/step - loss: 0.3510 - val_loss: 0.2705
# Epoch 2/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2624 - val_loss: 0.2503
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2387 - val_loss: 0.2258
# Epoch 4/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2184 - val_loss: 0.2092
# Epoch 5/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2046 - val_loss: 0.1976
# Epoch 6/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1944 - val_loss: 0.1886
# Epoch 7/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1862 - val_loss: 0.1811
# Epoch 8/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1793 - val_loss: 0.1749
# Epoch 9/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1734 - val_loss: 0.1693
# Epoch 10/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1681 - val_loss: 0.1644
# Epoch 11/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1634 - val_loss: 0.1599
# Epoch 12/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1593 - val_loss: 0.1560
# Epoch 13/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1555 - val_loss: 0.1524
# Epoch 14/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1521 - val_loss: 0.1492
# Epoch 15/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1490 - val_loss: 0.1461
# Epoch 16/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1461 - val_loss: 0.1433
# Epoch 17/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1433 - val_loss: 0.1407
# Epoch 18/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1407 - val_loss: 0.1380
# Epoch 19/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1382 - val_loss: 0.1356
# Epoch 20/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1358 - val_loss: 0.1332
# Epoch 21/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1335 - val_loss: 0.1310
# Epoch 22/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1313 - val_loss: 0.1288
# Epoch 23/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1292 - val_loss: 0.1267
# Epoch 24/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1271 - val_loss: 0.1246
# Epoch 25/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1252 - val_loss: 0.1228
# Epoch 26/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1233 - val_loss: 0.1209
# Epoch 27/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1216 - val_loss: 0.1192
# Epoch 28/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1199 - val_loss: 0.1176
# Epoch 29/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1184 - val_loss: 0.1161
# Epoch 30/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1169 - val_loss: 0.1147
# Epoch 31/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1156 - val_loss: 0.1134
# Epoch 32/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1144 - val_loss: 0.1122
# Epoch 33/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1132 - val_loss: 0.1111
# Epoch 34/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.1122 - val_loss: 0.1101
# Epoch 35/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1112 - val_loss: 0.1092
# Epoch 36/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1103 - val_loss: 0.1082
# Epoch 37/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1095 - val_loss: 0.1074
# Epoch 38/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1087 - val_loss: 0.1067
# Epoch 39/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1080 - val_loss: 0.1060
# Epoch 40/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1073 - val_loss: 0.1054
# Epoch 41/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1067 - val_loss: 0.1048
# Epoch 42/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1061 - val_loss: 0.1042
# Epoch 43/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1056 - val_loss: 0.1037
# Epoch 44/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1051 - val_loss: 0.1032
# Epoch 45/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1046 - val_loss: 0.1027
# Epoch 46/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1041 - val_loss: 0.1023
# Epoch 47/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1037 - val_loss: 0.1019
# Epoch 48/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1034 - val_loss: 0.1016
# Epoch 49/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.1030 - val_loss: 0.1012
# Epoch 50/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.1027 - val_loss: 0.1009

# %% [markdown]
# ## Testing autoencoder prediction

# %%
encoded_imgs = encoder.predict(x_test)
predicted = autoencoder.predict(x_test)

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display encoded images
    ax = plt.subplot(3, 20, i + 1 + 20)
    plt.imshow(encoded_imgs[i].reshape(8,4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e879b4fa0575> in <module>
#      12     # display encoded images
#      13     ax = plt.subplot(3, 20, i + 1 + 20)
# ---> 14     plt.imshow(encoded_imgs[i].reshape(8,4))
#      15     plt.gray()
#      16     ax.get_xaxis().set_visible(False)
#
# ValueError: cannot reshape array of size 2 into shape (8,4)

# %% [markdown]
# ## Testing autoencoder generation

# %%
import random
import numpy as np
X=[]
for i in range(10):
    data=[]
    for j in range(32):
        data.append(random.random())
    X.append(np.array(data))
X = np.array(X)
print(X.shape)

generated_imgs = decoder.predict(X)
# Out:
# (10, 32)

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X[i].reshape(8,4))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstructed images
    ax = plt.subplot(3, 20, i + 1 + 20)
    plt.imshow(generated_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  
    
plt.show()

# %% [markdown]
# ## Autoencoder encoding dim = 2

# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 2  

input_img = Input(shape=(784,))
decoder_input = Input(shape=(encoding_dim,))

encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

encoder = Model(input_img, encoded)
autoencoder=Model(input_img, decoded)

decoder_layer = autoencoder.layers[-1]
decoder = Model(decoder_input, decoder_layer(decoder_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.4419 - val_loss: 0.2774
# Epoch 2/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2744 - val_loss: 0.2714
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2707 - val_loss: 0.2690
# Epoch 4/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2688 - val_loss: 0.2678
# Epoch 5/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2677 - val_loss: 0.2668
# Epoch 6/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2669 - val_loss: 0.2661
# Epoch 7/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2663 - val_loss: 0.2657
# Epoch 8/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2657 - val_loss: 0.2652
# Epoch 9/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2653 - val_loss: 0.2648
# Epoch 10/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2648 - val_loss: 0.2643
# Epoch 11/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2643 - val_loss: 0.2637
# Epoch 12/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2631 - val_loss: 0.2614
# Epoch 13/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2587 - val_loss: 0.2550
# Epoch 14/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2534 - val_loss: 0.2515
# Epoch 15/50
# 60000/60000 [==============================] - ETA: 0s - loss: 0.251 - 1s 17us/step - loss: 0.2514 - val_loss: 0.2502
# Epoch 16/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2505 - val_loss: 0.2495
# Epoch 17/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2498 - val_loss: 0.2488
# Epoch 18/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2492 - val_loss: 0.2483
# Epoch 19/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2487 - val_loss: 0.2477
# Epoch 20/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2482 - val_loss: 0.2473
# Epoch 21/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2478 - val_loss: 0.2468
# Epoch 22/50
# 60000/60000 [==============================] - 1s 16us/step - loss: 0.2473 - val_loss: 0.2463
# Epoch 23/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2469 - val_loss: 0.2460
# Epoch 24/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2465 - val_loss: 0.2454
# Epoch 25/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2461 - val_loss: 0.2450
# Epoch 26/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2457 - val_loss: 0.2447
# Epoch 27/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2453 - val_loss: 0.2443
# Epoch 28/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2449 - val_loss: 0.2439
# Epoch 29/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2445 - val_loss: 0.2435
# Epoch 30/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2441 - val_loss: 0.2431
# Epoch 31/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2438 - val_loss: 0.2428
# Epoch 32/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2434 - val_loss: 0.2425
# Epoch 33/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2431 - val_loss: 0.2421
# Epoch 34/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2428 - val_loss: 0.2419
# Epoch 35/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2425 - val_loss: 0.2415
# Epoch 36/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2422 - val_loss: 0.2412
# Epoch 37/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2419 - val_loss: 0.2410
# Epoch 38/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2417 - val_loss: 0.2407
# Epoch 39/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2414 - val_loss: 0.2405
# Epoch 40/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2412 - val_loss: 0.2404
# Epoch 41/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2410 - val_loss: 0.2401
# Epoch 42/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2408 - val_loss: 0.2399
# Epoch 43/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2406 - val_loss: 0.2397
# Epoch 44/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2405 - val_loss: 0.2396
# Epoch 45/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2403 - val_loss: 0.2394
# Epoch 46/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2402 - val_loss: 0.2394
# Epoch 47/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2401 - val_loss: 0.2392
# Epoch 48/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2400 - val_loss: 0.2391
# Epoch 49/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2399 - val_loss: 0.2390
# Epoch 50/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2398 - val_loss: 0.2389

# %%
encoded_imgs = encoder.predict(x_train)

# %%
import matplotlib.pyplot as plt

plt.scatter(encoded_imgs[:,0], encoded_imgs[:,1], c=y_train, cmap="Paired")
plt.show()

# %% [markdown]
# ## Deep encoder

# %%
from keras.layers import Input, Dense
from keras.models import Model

encoding_dim = 2  

input_img = Input(shape=(784,))
decoder_input = Input(shape=(encoding_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

encoder = Model(input_img, encoded)
autoencoder=Model(input_img, decoded)

decoder_layer = autoencoder.layers[-1]
decoder = Model(decoder_input, decoder_layer(decoder_input))

autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 1s 20us/step - loss: 0.4387 - val_loss: 0.2773
# Epoch 2/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2740 - val_loss: 0.2706
# Epoch 3/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2688 - val_loss: 0.2655
# Epoch 4/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2628 - val_loss: 0.2590
# Epoch 5/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2572 - val_loss: 0.2548
# Epoch 6/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2543 - val_loss: 0.2529
# Epoch 7/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2530 - val_loss: 0.2519
# Epoch 8/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2521 - val_loss: 0.2512
# Epoch 9/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2514 - val_loss: 0.2504
# Epoch 10/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2508 - val_loss: 0.2499
# Epoch 11/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2503 - val_loss: 0.2494
# Epoch 12/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2498 - val_loss: 0.2490
# Epoch 13/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2494 - val_loss: 0.2486
# Epoch 14/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2489 - val_loss: 0.2481
# Epoch 15/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2485 - val_loss: 0.2477
# Epoch 16/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2482 - val_loss: 0.2473
# Epoch 17/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2478 - val_loss: 0.2469
# Epoch 18/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2474 - val_loss: 0.2466
# Epoch 19/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2471 - val_loss: 0.2463
# Epoch 20/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2468 - val_loss: 0.2460
# Epoch 21/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2464 - val_loss: 0.2456
# Epoch 22/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2461 - val_loss: 0.2454
# Epoch 23/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2458 - val_loss: 0.2451
# Epoch 24/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2455 - val_loss: 0.2448
# Epoch 25/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2452 - val_loss: 0.2444
# Epoch 26/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2449 - val_loss: 0.2442
# Epoch 27/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2446 - val_loss: 0.2439
# Epoch 28/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2443 - val_loss: 0.2435
# Epoch 29/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2441 - val_loss: 0.2433
# Epoch 30/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2438 - val_loss: 0.2430
# Epoch 31/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2435 - val_loss: 0.2427
# Epoch 32/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2433 - val_loss: 0.2425
# Epoch 33/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2430 - val_loss: 0.2421
# Epoch 34/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2428 - val_loss: 0.2420
# Epoch 35/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2425 - val_loss: 0.2416
# Epoch 36/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2423 - val_loss: 0.2414
# Epoch 37/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2420 - val_loss: 0.2413
# Epoch 38/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2418 - val_loss: 0.2411
# Epoch 39/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2416 - val_loss: 0.2408
# Epoch 40/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2414 - val_loss: 0.2406
# Epoch 41/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2412 - val_loss: 0.2404
# Epoch 42/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2410 - val_loss: 0.2401
# Epoch 43/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2408 - val_loss: 0.2400
# Epoch 44/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2406 - val_loss: 0.2399
# Epoch 45/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2405 - val_loss: 0.2397
# Epoch 46/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2403 - val_loss: 0.2395
# Epoch 47/50
# 60000/60000 [==============================] - 1s 18us/step - loss: 0.2402 - val_loss: 0.2394
# Epoch 48/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2401 - val_loss: 0.2393
# Epoch 49/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2399 - val_loss: 0.2392
# Epoch 50/50
# 60000/60000 [==============================] - 1s 17us/step - loss: 0.2398 - val_loss: 0.2390

# %%
encoded_imgs = encoder.predict(x_train)

import matplotlib.pyplot as plt

print(encoded_imgs[:,0])
print(encoded_imgs[:,1])

plt.scatter(encoded_imgs[:,0], encoded_imgs[:,1], c=y_train, cmap="Paired")
plt.show()
# Out:
# [ 5.51441097  2.02639151  2.64267468 ...,  5.22332668  3.65650201
#   3.97143936]
# [ 20.33519936  23.19351196  10.80878925 ...,  23.63227081  16.81074524
#   12.3301096 ]
