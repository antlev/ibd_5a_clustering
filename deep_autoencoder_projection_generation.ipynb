# %% [markdown]
# # MNIST import

# %%
from keras.datasets import mnist
import numpy as np
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers

encoding_dim = 2
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='sigmoid')(encoded)
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='relu')(decoded)

encoder = Model(input_img, encoded)
autoencoder=Model(input_img, decoded)

encoded_input = Input(shape=(encoding_dim,))
deco = autoencoder.layers[-3](encoded_input)
deco = autoencoder.layers[-2](deco)
deco = autoencoder.layers[-1](deco)
decoder = Model(encoded_input, deco)

autoencoder.compile(optimizer='adam', loss='logcosh')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))


encoded_imgs = encoder.predict(x_test)
predicted = autoencoder.predict(x_test)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.0358 - val_loss: 0.0316
# Epoch 2/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0299 - val_loss: 0.0289
# Epoch 3/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0278 - val_loss: 0.0271
# Epoch 4/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0264 - val_loss: 0.0259
# Epoch 5/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0253 - val_loss: 0.0250
# Epoch 6/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0245 - val_loss: 0.0243
# Epoch 7/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0239 - val_loss: 0.0238
# Epoch 8/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0235 - val_loss: 0.0235
# Epoch 9/50
# 60000/60000 [==============================] - 4s 67us/step - loss: 0.0232 - val_loss: 0.0231
# Epoch 10/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0228 - val_loss: 0.0228
# Epoch 11/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0225 - val_loss: 0.0226
# Epoch 12/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0224 - val_loss: 0.0225
# Epoch 13/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0223 - val_loss: 0.0224
# Epoch 14/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0221 - val_loss: 0.0222
# Epoch 15/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 16/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0219 - val_loss: 0.0220
# Epoch 17/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 18/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0217 - val_loss: 0.0219
# Epoch 19/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0216 - val_loss: 0.0216
# Epoch 20/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0214 - val_loss: 0.0216
# Epoch 21/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0213 - val_loss: 0.0216
# Epoch 22/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0213 - val_loss: 0.0216
# Epoch 23/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0212 - val_loss: 0.0215
# Epoch 24/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0211 - val_loss: 0.0215
# Epoch 25/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0210 - val_loss: 0.0214
# Epoch 26/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0209 - val_loss: 0.0212
# Epoch 27/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0209 - val_loss: 0.0211
# Epoch 28/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0208 - val_loss: 0.0211
# Epoch 29/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0207 - val_loss: 0.0209
# Epoch 30/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0205 - val_loss: 0.0207
# Epoch 31/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0204 - val_loss: 0.0207
# Epoch 32/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0203 - val_loss: 0.0207
# Epoch 33/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0202 - val_loss: 0.0205
# Epoch 34/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0201 - val_loss: 0.0204
# Epoch 35/50
# 60000/60000 [==============================] - 4s 68us/step - loss: 0.0201 - val_loss: 0.0205
# Epoch 36/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0200 - val_loss: 0.0204
# Epoch 37/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0200 - val_loss: 0.0203
# Epoch 38/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 39/50
# 60000/60000 [==============================] - 5s 77us/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 40/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 41/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0198 - val_loss: 0.0202
# Epoch 42/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0198 - val_loss: 0.0202
# Epoch 43/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0198 - val_loss: 0.0202
# Epoch 44/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0198 - val_loss: 0.0201
# Epoch 45/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0197 - val_loss: 0.0201
# Epoch 46/50
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0197 - val_loss: 0.0202
# Epoch 47/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0197 - val_loss: 0.0201
# Epoch 48/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0196 - val_loss: 0.0201
# Epoch 49/50
# 60000/60000 [==============================] - 4s 69us/step - loss: 0.0196 - val_loss: 0.0200
# Epoch 50/50
# 60000/60000 [==============================] - 4s 70us/step - loss: 0.0195 - val_loss: 0.0200

# %% [markdown]
# # Reduction de dimension + reconstruction

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(40, 4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display encoded images
    ax = plt.subplot(3, 20, i + 1 + 20)
    plt.imshow(encoded_imgs[i].reshape(2,1))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(predicted[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
  
    
plt.show()

# %% [markdown]
# # Projection de x_train en 2D

# %%
import matplotlib.pyplot as plt

encoded_imgs2 = encoder.predict(x_train)
plt.scatter(encoded_imgs2[:,0], encoded_imgs2[:,1], c=y_train, cmap="Paired")
plt.show()

# %% [markdown]
# # Projection de x_test en 2D

# %%
import matplotlib.pyplot as plt

plt.scatter(encoded_imgs[:,0], encoded_imgs[:,1], c=y_test, cmap="Paired")
plt.show()

# %% [markdown]
# # Generating random digits

# %%
generated_inputs = np.asarray([[x, y] for x in np.arange(0, 1, 0.1)
                               for y in np.arange(0, 1, 0.1)], dtype=np.float32)
generated = decoder.predict(generated_inputs)

# %%
import matplotlib.pyplot as plt

for i in range(100):
    # display original images
    ax = plt.subplot(10, 10, i + 1)
    plt.imshow(generated[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    
plt.show()

# %%
print(encoded_imgs[0])
# Out:
# [0.28326464 0.68898976]
